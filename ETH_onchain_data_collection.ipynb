# %% [markdown]
# <a href="https://colab.research.google.com/github/Altemir1/crypto-DL-based-trading-system/blob/main/ETH_onchain_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data collection using Alchemy API

# %% [markdown]
# Fetching data using AlchemyAPI

# %%
# !pip install web3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 580.7/580.7 kB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.5/100.5 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.5/301.5 kB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.6/169.6 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 46.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
#     Uninstalling websockets-14.2:
#       Successfully uninstalled websockets-14.2
# ...

# %%
API_KEYS = [
    "KKZ0Q90VyC1o3edkfNuVOZ61TYheR8dn",
    "TX0yMdgoPZUEduZK5sP9gKTBFQ5P26AT",
    "6_fm68ir0H9AqJOw4bP7MieABrZPPEwM",
]

# %%
import asyncio
import aiohttp
import random
import nest_asyncio
from web3 import Web3
from tqdm import tqdm
import time
import pandas as pd

# Fix event loop issue in Jupyter Notebook
nest_asyncio.apply()

# Function to get a random API key
def get_random_api_key():
    return random.choice(API_KEYS)

# Function to connect to Web3 using a random API key
def get_web3():
    api_key = get_random_api_key()
    provider_url = f"https://eth-mainnet.alchemyapi.io/v2/{api_key}"
    return Web3(Web3.HTTPProvider(provider_url))

# Define block range
START_BLOCK =  7000000  # Estimated start block for 2019 jan 2
END_BLOCK = 7400000 # Latest block number


# Estimate total batches
total_batches = (END_BLOCK - START_BLOCK)

# Function to fetch transactions **without async/await**
def fetch_block_transactions(block_number):
    web3 = get_web3()  # Get a new Web3 connection with a random key
    try:
        block = web3.eth.get_block(block_number, full_transactions=True)
        transactions = [
            {
                "timestamp": block.timestamp,
                "from": tx["from"],
                "to": tx["to"],
                "value": tx["value"] / 10**18,  # Convert Wei to ETH
                "gas_price": tx["gasPrice"] / 10**9,  # Convert Wei to Gwei
                "hash": tx["hash"].hex()
            }
            for tx in block.transactions
        ]
        return transactions
    except Exception as e:
        print(f"Error fetching block {block_number}: {e}")
        return []

# Main function to fetch all transactions (running in parallel batches)
def fetch_all_transactions():
    block_count = 0
    all_transactions = []
    with tqdm(total=total_batches, desc="Fetching Blocks", unit="batch") as pbar:
        for block in range(START_BLOCK, END_BLOCK):
            block_count += 1
            txs = fetch_block_transactions(block)
            all_transactions.extend(txs)
            pbar.update(1)  # Update progress bar

            # Avoid rate limit by sleeping for a short duration
            time.sleep(0.5)


    return all_transactions

# %%
all_transactions = fetch_all_transactions()
# Out:
# Fetching Blocks:   0%|          | 17/400000 [00:12<78:48:17,  1.41batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2f2f5de8644f> in <cell line: 0>()
# ----> 1 all_transactions = fetch_all_transactions()
#
# <ipython-input-4-69c2e4f41cc1> in fetch_all_transactions()
#      62
#      63             # Avoid rate limit by sleeping for a short duration
# ---> 64             time.sleep(0.5)
#      65
#      66
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(all_transactions)
df.head()
# Out:
#     timestamp                                        from  \
# 0  1561100149  0xBcD44f9795cddD1358dcC3bEF160772FcD607CA4
# 1  1561100149  0xa93b74DA13F39e5E558e2037034A43F0456E7b8B
# 2  1561100149  0x5E032243d507C743b061eF021e2EC7fcc6d3ab89
# 3  1561100149  0x4c8006474754C6D3E14463aa9c863FB66F4ADa22
# 4  1561100149  0xfeBE9573660c42BC582cFFd1088f3716f4cfc449
#
#                                            to     value  gas_price  \
# 0  0x8E71B195D9CC953F46f41aD013bA1147464b621d  3.225223      100.0
# 1  0x3597bfD533a99c9aa083587B074434E61Eb0A258  0.000000       99.0
# 2  0xBF37A0D9D0fb49e876cc685afAfD581F8F136306  0.874485       60.0
# 3  0x06404399e748CD83F25AB163711F9F4D61cfd0e6  0.000000       50.0
# 4  0xeF06A35c1928B655AbA17fe637F066CD8EfF9B7e  0.010000       41.0
#
#                                                 hash
# 0  ef1ef76dc23bd29ddb64c373897e5b4430766cf08d11f4...
# 1  b4e2d06aff9b0a42662f6b34904aa7229802d230e0c253...
# ...

# %%
df.shape
# Out:
# (23860, 6)

# %%
df["date"] = df.timestamp.apply(lambda x: time.strftime('%Y-%m-%d', time.localtime(x)))
df.drop(columns=["timestamp"], inplace=True)

df.head()
# Out:
#                                          from  \
# 0  0xBcD44f9795cddD1358dcC3bEF160772FcD607CA4
# 1  0xa93b74DA13F39e5E558e2037034A43F0456E7b8B
# 2  0x5E032243d507C743b061eF021e2EC7fcc6d3ab89
# 3  0x4c8006474754C6D3E14463aa9c863FB66F4ADa22
# 4  0xfeBE9573660c42BC582cFFd1088f3716f4cfc449
#
#                                            to     value  gas_price  \
# 0  0x8E71B195D9CC953F46f41aD013bA1147464b621d  3.225223      100.0
# 1  0x3597bfD533a99c9aa083587B074434E61Eb0A258  0.000000       99.0
# 2  0xBF37A0D9D0fb49e876cc685afAfD581F8F136306  0.874485       60.0
# 3  0x06404399e748CD83F25AB163711F9F4D61cfd0e6  0.000000       50.0
# 4  0xeF06A35c1928B655AbA17fe637F066CD8EfF9B7e  0.010000       41.0
#
#                                                 hash        date
# 0  ef1ef76dc23bd29ddb64c373897e5b4430766cf08d11f4...  2019-06-21
# 1  b4e2d06aff9b0a42662f6b34904aa7229802d230e0c253...  2019-06-21
# 2  3027cd8fa04ba932ccbd549cdb3a48e5c3088bf52512e1...  2019-06-21
# ...

# %%
df.to_csv("eth-onchain-data.csv")

# %% [markdown]
# # Data collection using Google BigQuery Databases

# %%
# !pip install google-cloud-bigquery

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import bigquery
client = bigquery.Client()

# %%
query = """SELECT block_number, timestamp, miner, transaction_count
FROM `blockchain_analytics_ethereum_mainnet_us`
WHERE block_number BETWEEN 10000000 AND 10400000
ORDER BY block_number
LIMIT 1000
"""

# Run query and store results in a DataFrame
df = client.query(query).to_dataframe()

# Display first 5 rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-13-c087afc44a97> in <cell line: 0>()
#       7
#       8 # Run query and store results in a DataFrame
# ----> 9 df = client.query(query).to_dataframe()
#      10
#      11 # Display first 5 rows
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/bigquery/client.py in query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3500             )
#    3501         elif api_method == enums.QueryApiMethod.INSERT:
# -> 3502             return _job_helpers.query_jobs_insert(
#    3503                 self,
#    3504                 query,
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/bigquery/_job_helpers.py in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
# ...

# %%
from google.cloud import bigquery

client = bigquery.Client()

# List datasets in the public BigQuery project
datasets = list(client.list_datasets("bigquery-public-data"))

print("Available datasets in `bigquery-public-data`:")
for dataset in datasets:
    print(dataset.dataset_id)
# Out:
# Available datasets in `bigquery-public-data`:
# america_health_rankings
# austin_311
# austin_bikeshare
# austin_crime
# austin_incidents
# austin_waste
# baseball
# bbc_news
# bigqueryml_ncaa
# bitcoin_blockchain
# blackhole_database
# blockchain_analytics_ethereum_mainnet_us
# bls
# bls_qcew
# breathe
# broadstreet_adi
# catalonian_mobile_coverage
# catalonian_mobile_coverage_eu
# census_bureau_acs
# census_bureau_construction
# census_bureau_international
# census_bureau_usa
# census_opportunity_atlas
# census_utility
# cfpb_complaints
# chicago_crime
# chicago_taxi_trips
# clemson_dice
# cloud_storage_geo_index
# cms_codes
# cms_medicare
# cms_synthetic_patient_data_omop
# country_codes
# covid19_aha
# covid19_covidtracking
# covid19_ecdc
# covid19_ecdc_eu
# covid19_genome_sequence
# covid19_geotab_mobility_impact
# covid19_geotab_mobility_impact_eu
# covid19_google_mobility
# covid19_google_mobility_eu
# covid19_govt_response
# covid19_italy
# covid19_italy_eu
# ...
